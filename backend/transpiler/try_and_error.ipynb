# %%
import networkx as nx
import json

g = {}

with open('xmlExamples/graphology_model_small.json') as file:
    js_graph = json.load(file)
    g = nx.readwrite.node_link_graph(js_graph)
    print(g)

nx.draw_kamada_kawai(g)
# Out:
# Graph with 76 nodes and 75 edges

# %%
with open('xmlExamples/graphology_model_small.json') as file:
    js_graph = json.load(file)
    g = nx.readwrite.node_link_graph(js_graph)
    print(g)

nx.draw_planar(g)
# Out:
# Graph with 76 nodes and 75 edges

# %%
with open('xmlExamples/graphology_model_small.json') as file:
    js_graph = json.load(file)
    g = nx.readwrite.node_link_graph(js_graph)
    print(g)

nx.draw_spring(g)
# Out:
# Graph with 76 nodes and 75 edges
